# %%
# %load_ext autoreload

# %%
from lovely_tensors.patch import monkey_patch

monkey_patch()
import torch
from transformers import GPT2Tokenizer
import wandb
from tqdm.auto import tqdm

# %%
with open("tiny_shakespeare.txt", "r") as f:
    data = f.read()
chars = sorted(list(set(data)))

# create a mapping from characters to integers
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}


def encode(s):
    return [stoi[c] for c in s]  # encoder: take a string, output a list of integers


def decode(l):
    return "".join(
        [itos[i] for i in l]
    )  # decoder: take a list of integers, output a string

encoded_data = encode(data)

# %%
train_data = encoded_data[: int(len(encoded_data) * 0.8)]
val_data = encoded_data[int(len(encoded_data) * 0.8) :]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_data = torch.tensor(train_data).to(device)
val_data = torch.tensor(val_data).to(device)

# %%
def get_item(data, ctx):
    # i = random.randint(0, len(data) - ctx - 1)
    i = 0
    while i + ctx < len(data):
        src = data[i : i + ctx]
        dst = data[i + 1 : i + ctx + 1]
        yield src, dst
        i += ctx


def get_epoch(data, ctx_len, batch_size, shuffle=True):
    """Yields a tuple of tensors of shape (batch_size, ctx).
    X, shape=B C
    y, shape=B C
    """

    items = get_item(data, ctx_len)

    try:
        while True:
            X, y = zip(*[next(items) for _ in range(batch_size)])
            yield torch.stack(X), torch.stack(y)
    except StopIteration:
        pass

# %%
import random


def get_random_item(data, ctx):
    i = random.randint(0, len(data) - ctx - 1)

    src = data[i : i + ctx]
    dst = data[i + 1 : i + ctx + 1]

    return src, dst


def get_batch(data, ctx_len, batch_size, shuffle=True):
    """Yields a tuple of tensors of shape (batch_size, ctx).
    X, shape=B C
    y, shape=B C
    """

    batch = [get_random_item(data, ctx_len) for _ in range(batch_size)]
    X, y = zip(*batch)

    return torch.stack(X), torch.stack(y)


get_batch(train_data[:100], ctx_len=5, batch_size=2)
# Out:
# (tensor[2, 5] i64 n=10 x∈[0, 56] μ=37.700 σ=18.833 cuda:0 [[43, 44, 53, 56, 43], [10, 0, 31, 54, 43]],
#  tensor[2, 5] i64 n=10 x∈[0, 56] μ=36.400 σ=20.354 cuda:0 [[44, 53, 56, 43, 1], [0, 31, 54, 43, 39]])

# %%
def model(params, input_ids, vocab_size):
    """This model takes in a sequence and predicts 1 token"""

    one_hot_inputs = torch.nn.functional.one_hot(input_ids, num_classes=vocab_size)
    one_hot_inputs = one_hot_inputs.float()

    embeddings = one_hot_inputs @ params["embedding"].T  # N, CTX_LEN, EMBEDDING_DIM

    # preds = hidden_states[:, -1, :] # @ params["w"]

    hidden_state = (
        embeddings.view((input_ids.shape[0], -1)) @ params["w1"].T + params["b1"]
    )
    hidden_state = torch.nn.functional.relu(hidden_state)

    hidden_state = (
        hidden_state.view((input_ids.shape[0], -1)) @ params["w2"].T + params["b2"]
    )
    hidden_state = torch.nn.functional.relu(hidden_state)

    preds = hidden_state @ params["embedding"]

    return preds

# %%
def generate(model, model_params, ctx_len, encoded_prompt, n_tokens):
    """Generate n_tokens after prompt"""
    with torch.no_grad():
        # encoded_prompt = torch.tensor(encoded_prompt).to(device).unsqueeze(0)
        for _ in range(n_tokens):
            # print(encoded_prompt)
            preds = model(
                model_params, encoded_prompt[:, -ctx_len:], vocab_size=len(chars)
            )
            next_token = torch.argmax(preds, dim=1, keepdim=True)
            # print(f"{next_token=}")
            encoded_prompt = torch.cat([encoded_prompt, next_token], dim=1)
    return encoded_prompt

# %%
CTX_LEN = 12

EMBEDDING_DIM = 128

INTERMEDIATE_DIM = EMBEDDING_DIM * 8

BATCH_SIZE = 4096
LR = 0.1
LOG_INTERVAL = (len(train_data) // (BATCH_SIZE * CTX_LEN) // 10) + 1
VALIDATION_INTERVAL = (len(train_data) // (BATCH_SIZE * CTX_LEN) // 5) + 1
TRAIN_TOKENS = len(train_data) * 30


run = wandb.init(
    # set the wandb project where this run will be logged
    project="my-awesome-project",
    entity="llmnerds",
    config={
        "batch_size": BATCH_SIZE,
        "ctx": CTX_LEN,
    },
)

model_params = {
    "embedding": torch.randn((EMBEDDING_DIM, len(chars)), device=device),
    "w1": torch.randn((INTERMEDIATE_DIM, EMBEDDING_DIM * CTX_LEN), device=device),
    "b1": torch.randn((INTERMEDIATE_DIM,), device=device),
    "w2": torch.randn((EMBEDDING_DIM, INTERMEDIATE_DIM), device=device),
    "b2": torch.randn((EMBEDDING_DIM,), device=device),
    # "classifier": torch.randn(
    #     (INTERMEDIATE_DIM, len(chars)), device=device, requires_grad=True
    # ),
}

# # glorot init
for p in model_params.values():
    if len(p.shape) == 2:
        torch.nn.init.kaiming_normal_(p)
    p.requires_grad = True


i = 1
total_loss = 0
val_total_loss = 0

token_count = 0
optim = torch.optim.Adam(model_params.values(), lr=1e-3)

# batch_gen = get_batch(train_data, ctx_len=CTX_LEN, batch_size=BATCH_SIZE, shuffle=True)
with run:
    while token_count < TRAIN_TOKENS:
        X, y = get_batch(train_data, ctx_len=CTX_LEN, batch_size=BATCH_SIZE, shuffle=True)

        token_count = i * BATCH_SIZE * CTX_LEN

        preds = model(params=model_params, input_ids=X, vocab_size=len(chars))
        loss = torch.nn.functional.cross_entropy(input=preds, target=y[:, -1])
        total_loss += loss.item()
        loss.backward()

        with torch.no_grad():
            optim.step()
            optim.zero_grad()

            # for param in model_params.values():
            #     param -= LR * param.grad
            #     param.grad.zero_()

        if i % LOG_INTERVAL == 0:
            wandb.log(
                {
                    "loss": total_loss / LOG_INTERVAL,
                    "epoch": token_count // len(train_data),
                },
                step=token_count,
            )
            total_loss = 0

        if i % VALIDATION_INTERVAL == 0:
            j = 0
            for X_val, y_val in get_epoch(
                val_data, ctx_len=CTX_LEN, batch_size=4096, shuffle=False
            ):
                with torch.no_grad():
                    preds = model(
                        params=model_params, input_ids=X_val, vocab_size=len(chars)
                    )
                    loss = torch.nn.functional.cross_entropy(preds, y_val[:, -1])
                    val_total_loss += loss.item()
                    j += 1
            wandb.log({"val_loss": val_total_loss / j}, step=token_count, commit=True)

            prompts = get_batch(val_data, ctx_len=CTX_LEN, batch_size=5)[0].to(device)
            generated = generate(
                model=model,
                model_params=model_params,
                encoded_prompt=prompts,
                ctx_len=CTX_LEN,
                n_tokens=CTX_LEN * 2,
            )
            for p in generated:
                char_list = p.tolist()
                pre_prompt = char_list[:CTX_LEN]
                post_prompt = char_list[CTX_LEN:]

                print(f"{repr(decode(pre_prompt))}-> {repr(decode(post_prompt))}")

            val_total_loss = 0
        i += 1
# Out:
# wandb version 0.15.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.10
# Run data is saved locally in <code>/home/xl0/work/projects/transformers/wandb/run-20230930_201424-a20m2ovc</code>
# Syncing run <strong><a href='https://wandb.ai/llmnerds/my-awesome-project/runs/a20m2ovc' target="_blank">robust-wave-140</a></strong> to <a href='https://wandb.ai/llmnerds/my-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/llmnerds/my-awesome-project' target="_blank">https://wandb.ai/llmnerds/my-awesome-project</a>
#  View run at <a href='https://wandb.ai/llmnerds/my-awesome-project/runs/a20m2ovc' target="_blank">https://wandb.ai/llmnerds/my-awesome-project/runs/a20m2ovc</a>
# 'bour\nIs the '-> '                        '
# 'ignior Petru'-> '                        '
# 'are gentleme'-> '                        '
# ':\nOne, Kate,'-> '                        '
# 'ind when he '-> '                        '
# ',\nAnd say sh'-> '   n                    '
# '\nOf palsied '-> 'an  an  on  on  on  on  '
# 'o thee belon'-> '  o   an   n   an  on  o'
# 'athers commo'-> '  o   n                 '
# 'he duke gone'-> ' an  he  on  on  on  on '
# 'o you, trenc'-> ' the    t               '
# 'part\nWas apt'-> ' the  o t  t            '
# 'hall see how'-> '  oe the    t           '
# 'ckless, and '-> 'the    t                '
# 'schance of\nt'-> ' t  t e  t t            '
# '\nISABELLA:\nH'-> 'e  oo  oo  hor  ore ror '
# 'leep,\nDreami'-> 'n the  ore io the  ooe  '
# 'ut up my tho'-> 'r  oo  hor  ore ror  oo '
# 'In cypress c'-> 'or  oo  ore tore toe  oo'
# ' for the ent'-> 'he  oo  oo  oo  oo  oo  '
# 'ignior Lucio'-> '  oo  hor  oo  oor sore '
# ' will your h'-> 'or sore sor sor  oor sor'
# 'one,\nThough '-> 'so  oo  oo  oor sore sor'
# ' time to spe'-> ' so  oo  oo  oor sore so'
# 'of it.\n\nDUKE'-> ' the  oo  oo  oor sore s'
# 'mes.\nSay tha'-> 't  an the  an the  oo  o'
# 'th a shrew,\n'-> 'the  oo  oo  oor tore th'
# "at the gate'"-> ' the  an  no  oo  oor to'
# 't request to'-> ' the  ane the  an  no  o'
# 'I am no chil'-> ' the  ane the  an  no  o'
# 'f this man.\n'-> '\n\n\nwEEEEEEE:\n\n\nEEEEEEE:\n'
# 'der thy tabl'-> 'e sor so the sore the be'
# "atter'd her "-> 'the se sore the bere the'
# "'twixt your "-> 'sore the bere the  ane t'
# 'or his sake;'-> ' an the so the be the be'
# ' more penite'-> ' the the the the the the'
# ' your pupils'-> ' so the the the the the '
# "llows, let's"-> ' the the the the the the'
# ' catch.\nBut '-> 'the the the the the the '
# 'believe ther'-> ' the the the the the the'
# '\nSignior Hor'-> 'e the the the the the th'
# ' do what I a'-> 'n the the the the the th'
# 'o?\n\nBIONDELL'-> ':\n\nE\nEEEEEEEE:\nE:\nE:\nEE:'
# 'oth,\nThese a'-> 'n the the the the the th'
# 'o the gaol. '-> '\nou the the the the the '
# 'man.\n\nPROSPE'-> 'E:\nEo the  ou the cout t'
# ' the less, m'-> 'e the the the bor sor th'
# ' you, sirrah'-> 'e the bere the be the be'
# "LUCIO:\nI'll "-> 'we the the the bor sor t'
# 'er: what che'-> ' s and the the the bor s'
# 'limb, nor be'-> ' the be the be the be th'
# 'k! I hear th'-> 'e be the be the be the b'
# 'd her volubi'-> 'ng the sour the soun the'
# 'nd horn.\n\nVI'-> 'NG the the beat or hou t'
# 'the house of'-> ' his the be the be the b'
# 'ed to your w'-> 'ing the sour the she the'
# 'hat a blow w'-> 'ith sour tor soun the so'
# 'll murder me'-> ' the soun the soun the s'
# 'e son being '-> 'the she the beat ou hour'
# 'he vouches, '-> 'be the she hat hou hat s'
# ' and light--'-> ' are the sore the wing t'
# "Nathaniel's "-> 'tor sour sor sour sor so'
# 'ior,\nAm bold'-> ' the sour sor she the wa'
# ' under my co'-> 'ur the southe the wist o'
# ' things neat'-> ' the wath the wath the w'
# 'can.\n\nPROSPE'-> 'S:\nThe s and se and the '
# 'was not come'-> ' the the hat he seat and'
# 'w my decease'-> ' the be the fare the hat'
# 'ver too late'-> ' the the the be the fare'
# 'sure\nfrom hi'-> 's the seat and the the h'
# '\nAs is the o'-> 'ur that the be the the t'
# 'in hand:\nShe'-> ' that the wing that the '
# ' law than An'-> 'd seat the that that the'
# 'confess the '-> 'seathe that with the ber'
# 'babe.\n\nBAPTI'-> 'NIA:\nThe have the wing t'
# 'e to make so'-> 'ur the seathe the wart o'
# 'nce there wa'-> 'th the be the the wart o'
# '\n\nKATHARINA:'-> '\nI I le the seat ou the '
# 't gives not '-> 'he the warl the wing the'
# 'lead these g'-> 'ot the sere the wing the'
# 'e Claudio\nan'-> 'd the be the fore the wi'
# 'sins and ewe'-> ' the with the berst for '
# 'at, being ma'-> 'nd the be the fore the w'
# 'uch duty as '-> 'the be the fore the wing'
# 't this habit'-> 'h the berst for the beth'
# 'mour.\n\nBIOND'-> 'ES:\nThe seat the wing th'
# ', awake! tho'-> 'u doun the fore the wing'
# ' muscadel\nAn'-> ' the with the ward the w'
# '\nshrift and '-> 'sour the for soul seat h'
# 'vost:\nWhat c'-> 'ound the be the fore the'
# '.\n\nLord:\nHea'-> 't you the the the ward t'
# 't wiselier t'-> 'he the sore the wing the'
# 'other laced,'-> ' the the the ward the wa'
# 'e with Trani'-> 'the the sore the wing th'
# 'it on any ot'-> ' the ward the ward the w'
# 'ill marry yo'-> 'ur to hare the sour to t'
# '\ngentleman o'-> 'ur the ward the ward the'
# ' written in '-> 'the the sore to the ward'
# ' yourself fo'-> 'r the fore the soor to t'
# 'r should\nBe '-> 'sour the sour to the hat'
# 'welcome.--\nS'-> 'or with the beathe seare'
# 'ng is this i'-> 'n the beather the wing t'
# 'er had direc'-> 'e the seare the seare th'
# '\n\nCLAUDIO:\nM'-> 'o the sour wing the sand'
# 'w than Angel'-> 'e the sand and mand and '
# "fter-dinner'"-> 's the here the sore the '
# 'al cook?\nHow'-> ' the sere the sore the s'
# 'id your mist'-> ' on the be the seare the'
# 'y; and I\ntru'-> 's the sear so the seare '
# '\n\nBIONDELLO:'-> '\nSor sore the sore the s'
# "r suit's unp"-> 'ere the soor sore the so'
# 'from your be'-> 'nter and the sould the t'
# "rest o' the "-> 'sour sour to the sour to'
# '; there to v'-> 'ere the soor sore the so'
# '\nWho, not th'-> 'e sould the the sore the'
# 'come from Pi'-> 's the fore the wing the '
# 'arm\nI have a'-> 'nd the wing the wing the'
# 'that?\n\nHORTE'-> 'LIA:\nI his dear the with'
# ' my merry mi'-> 'ng the wing the wing the'
# 'he instrumen'-> 't the with the be the wi'
# 'sweet Kate, '-> 'that whe dour and the so'
# ' help of her'-> 'e the sour werthe sous t'
# ' of stocks, '-> 'and the sore that shall '
# ' silence! tr'-> 'ee the seare to mane the'
# 'ned for untr'-> 'es me the sour of the so'
# 'A:\nIn his to'-> ' the wing the will what '
# 'in your comm'-> 'ent the here were the wi'
# 'y to her hea'-> 'r whell be will the will'
# ' with that\nW'-> 'her the seare the wing t'
# 'vote to Aris'-> 't the here were the will'
# 'nters more r'-> 'eat the sour with the so'
# '\nMust stead '-> 'and the seare to mane th'
# 'go in your p'-> 'ordere to me the werd of'
# 't thou\nDeser'-> 'e the sorder the sour wi'
# 'idal dinner:'-> '\nWhe har the sand the so'
# 'ook some car'-> 'd the sord with the song'
# ',\nBut my ent'-> 'her the sear the sorder '
# 'ostess:\nYou '-> 'have the here the here t'
# 'drink; thy f'-> 'ord with the songer the '
# ' soul--\nNo, '-> 'I ward the sord with the'
# 'y mistress? '-> 'the sous that the with t'
# 'ed that ther'-> ' the with the with the w'
# 'wn lie, he d'-> 'and the with the with th'
# 'als in Bianc'-> 'e the sone that the with'
# 'hat be all, '-> 'we the with the with the'
# ' him a bette'-> 'r the the sould the buth'
# 'eshmonger, a'-> 'nd the reath me to the s'
# 'ite of the f'-> 'or the fore that the wil'
# 'with a costl'-> 'e sour the with the beat'
# 's forsworn; '-> 'the sould the buth the s'
# 'ay seem as s'-> 'hat the farth mand and t'
# 'essed youth\n'-> 'Wour have a the pore to '
# 'ther tell hi'-> 's the farting and the so'
# ' her love fo'-> 'r the forth mand and the'
# '\nFRANCISCO:\n'-> 'Nor, and the parting and'
# ' perfidious!'-> '\n\nFor the have the with '
# 'Baptista, le'-> ' the word with her the h'
# '!\n\nDUKE VINC'-> 'ERIARI I and the the her'
# 't mind the p'-> 'row the sord with her th'
# ' the deck, i'-> 'n the the with he hard o'
# "lities o' th"-> 'e forth sould with here '
# 'an old trot '-> 'the words the beard and '
# 'son and my s'-> 'eart the sould the beart'
# 'te.\n\nLUCENTI'-> ' I have to be the with a'
# 'My master is'-> ' the forth sould with he'
# 'uty.\n\nDUKE V'-> 'ORIORARUS:\nI that the sh'
# 'nster, a\nver'-> ' the sour that the wart '
# ' is not she.'-> '\n\nGLOUCESTER:\nI sand the'
# 'he nursing\na'-> 'nd sand the sond the son'
# 'ost affect.\n'-> '\nCARIOLA:\nI will me the '
# 'erance. But '-> 'the the hear the hath an'
# ', when once '-> 'the the hear the hath an'
# ' would were '-> 'the have the hear the ha'
# 'ee, Licio, t'-> 'he beat the the the hath'
# 'ow.\nYou are '-> 'the here the here the he'
# "'Twas you we"-> 're and the tore and mane'
# 'er\nnow stand'-> ' the the hare of the sou'
# 'Father, be q'-> 'ueen the sare and to the'
# '\nTo do me bu'-> 't on the stand the the h'
# 'ds the breat'-> ' the sore the sore to th'
# 'nted skin co'-> 'me the sone the sone the'
# 'est.\n\nDUKE V'-> 'ORY:\nAnd with my hat the'
# 'hy\nDoth it n'-> 'ot the with the sand and'
# 'ta too.\nUpon'-> ' the sand of the has so '
# '. Look, the '-> 'sand the east the hat he'
# 'ager thou ha'-> 's that we the souse to b'
# 'el,\nAnd did '-> 'the forther bear the wit'
# "im'd it open"-> 'ter to the searter to th'
# 'e. Is this t'-> 'he for her bear the with'
# 'e men.\n\nBoat'-> ' I have the word with th'
# 'nt.\n\nISABELL'-> 'A:\nI me to my to the sou'
# 'er instantly'-> ' to the soust the words '
# 'o have heari'-> 'ng the seart the with th'
# 'lse new form'-> 'e to the worth the with '
# 'most clear d'-> 'o the sorther worth the '
# ' husband\nKno'-> 't the with the seart the'
# 'have no more'-> ' and the will and here t'
# 'rent, made i'-> 't at and the farth and t'
# ' with aches,'-> ' and the forth and the f'
# 't news abroa'-> 'd have the with the sear'
# 't shall be m'-> 'one the sould the prous '
# 'wn her love?'-> '\n\nMENENIUS:\nWhat so my t'
# 'r with berri'-> 'ng and the prould the so'
# 'to marry wit'-> 'h the prother the sould '
# ' young schol'-> 'd sould the prous the so'
# ' give me lea'-> 'r the with the prowe hav'
# 's love.\nSay,'-> ' that we have the word w'
# 'er\nvirtue to'-> ' the prown the sone that'
# 'hounds and h'-> 'er with the prowe have a'
# 'of\npeach-col'-> 'd with the prowe have an'
# ' this speech'-> 'is to the prown the song'
# 'rave attenda'-> 'nd the will sour his wit'
# 'hose advice\n'-> 'The seart the will sour '
# 'prised,\nAs l'-> 'ord and the will sour hi'
# 'ge:\nNay, it '-> 'we be the the with the r'
# 'ed within th'-> 'e shall be the ford with'
# ' company\nAt '-> 'with my lord, the sore t'
# " 't shall be"-> ' the ford with the have '
# 'uence; it mu'-> 'st the have the here of '
# 'd teach me h'-> 'ave hath and the from th'
# 'the rheum,\nF'-> 'or the the his the sore '
# 'r; but you w'-> 'ith the prown this fare '
# '\nAs will a c'-> 'our the that that the wi'
# ' believe I k'-> 'ing the with the sore th'
# 'arrel since '-> 'the sender the with a de'
# 'rt deceived '-> 'and the seare the with a'
# ' thirty, a p'-> 'artine so his all the wi'
# ': but as he '-> 'hand the seare the with '
# 'titions in t'-> 'he sould the with a say '
# 'ude beast wi'-> 'th a seart the with a sa'
# 'n innocency,'-> ' and the seart of the fo'
# 'o worse issu'-> 'll the bear the with the'
# 'vens thank y'-> 'ou dear the with the son'
# 'casa ben ven'-> 'ter the word the songer '
# 'c ear\nProfes'-> 't the soner be and the w'
# 'hese braves '-> 'and the with the hath an'
# ' good time: '-> 'the with the hath and th'
# ' thee,\nthoug'-> 'h the hath and the with '
# ' mean array.'-> '\n\nCOMIOLANUS:\nWhat the f'
# "As e'er I he"-> 'ar the forth and the wit'
# 'ETRUCHIO:\nYo'-> 'u shall seed the with th'
# 'en an unlawf'-> ' the seare the well and '
# 'CENTIO:\nLet '-> 'me the with the prould t'
# 'ARINA:\nO the'-> ' dor the will the well a'
# 'r blood,\nAnd'-> ' seed the well the well '
# 'y brother ju'-> 'st and the with the prot'
# 'ou courtesy,'-> '\nThat shall be the propl'
# 'tent ministe'-> 'r to the propless the be'
# ', which she '-> 'have be not the but and '
# 'love.\n\nANGEL'-> 'O:\nI have be not the but'
# 'ess: perchan'-> 'd the with the with the '
# 's\nhereafter,'-> ' the with the with the w'
# ' for:\nTake u'-> 's the torther to mane th'
# 'h you!\n\nProv'-> 'er the will the with the'
# ' he goes but'-> ' the will the with the w'
# 'oung one.\n\nP'-> 'AREINA:\nI well me the he'
# 'ht.\n\nLUCENTI'-> 'A:\nI seave the heart the'
# 'ing;\nAnd her'-> ' the shall the with the '
# 'aster and\nmi'-> 'ne the stand the the hat'
# 'er name fair'-> ' the will the with the s'
# 'cted him to '-> 'me the with the sarder h'
# 'ke heed\nhe h'-> 'ave the wart the sander '
# 'evil that th'-> 'e parter the sore that h'
# ' your sister'-> ' to mare the farter to m'
# 'ship; in the'-> ' sore that have to shall'
# "est. Is't no"-> 't be and the should be t'
# 'E VINCENTIO:'-> '\nWhat should be the sour'
# 'igence!\nAwak'-> ' his the sould the word '
# ' these unrev'-> 'enter the sore to the so'
# 'lear\nAs morn'-> ' the sones the soor with'
# 'hy wind,\nif '-> 'the for the forth the so'
# 'owing--\nDost'-> ' the seed a the word the'
# 'maintained a'-> ' the with the deard and '
# 'e amazed at '-> 'the sould the when the s'
# 'First kiss m'-> 'e with the deard and the'
# 'ow out of th'-> 'e forth the sould the wo'
# '.\nBut where '-> 'the sould the worth the '
# 'ore, I pray '-> 'the songer to the good t'
# 'y this gentl'-> 'e and the counder the so'
# ' modesties;\n'-> 'And there as the sone of'
# 'ith a larges'-> ' the songer of the songe'
# 'not moonligh'-> 't the sone of the songer'
# 'nd about the'-> ' sone the sond the sond '
# '.\n\nPROSPERO:'-> '\nAnd shat the that the s'
# 'ces from tho'-> 'u have hear be the sound'
# 'so soon forg'-> 'er to sould with a seare'
# '.\n\nPROSPERO:'-> '\nAnd shat should and wit'
# 'he the verie'-> 'n of the sees and with s'
# "l me 'lord:'"-> 'd the sone of the sous o'
# 'u shall be m'-> 'e the sould the sees of '
# ' do fear the'-> ' will the weat the seart'
# 'and; yet my '-> 'lord,\nAnd the the stall '
# 'her withal.\n'-> '\nKING RICHARD III:\nWhy s'
# 'e it full.\nW'-> 'hich dear his be the but'
# 'way;\nAnd the'-> 're a strang the words of'
# 'ed with yell'-> ' the heart the with the '
# 'prisoner. Fa'-> 'rs of the to the with th'
# "o 't. But th"-> 'e the with the with the '
# 'd.\n\nKATHARIN'-> 'GARUCHARD III:\nWhy shat '
# ', sir,\nThan '-> 'the the with the with th'
# 'e matter out'-> ' the with a beare the we'
# '\nTRANIO:\nGra'-> 'y she here of the will a'
# 'MARIANA:\nWhy'-> ', the seare the well as '
# 'God! what ma'-> 'y she will as the will a'
# '.\n\nPROSPERO:'-> '\nAnd shat the well and h'
# 'ke her hence'-> ' the sarted the with a b'
# 'with dew:\nSa'-> 'y, then the with a but t'
# 'nd doth beg '-> 'the with a but the stain'
# ' in truth an'-> 'd the stall the with a b'
# 'g-on; methin'-> 'g the with a but the sta'
# 'ome to serve'-> 'r there with a prown wit'
# ' farewell, S'-> 'or the will and with the'
# 'ly what his\n'-> 'And well him and the wit'
# 'nge.\nSea-nym'-> 'e and the reath a peart '
# 'u, sir.\n\nVIN'-> 'G EDWARD IV:\nNow, what s'
# 'gh the instr'-> 'ess the son the sees the'
# 'He does it u'-> 's a seart the stall the '
# "ntertain'd t"-> 'he stall the beather tha'
# 'to try with '-> 'the seave the with the s'
# 'd of her, ha'-> 've me the seed the stall'
# 'loath:\nI wou'-> 'ld be so shall shall be '
# '\nHow to deny'-> ' the songer of the son t'
# "wife?\nThou'l"-> 'l the prow the seare to '
# 'daughter, fe'-> 'llow the songer of the s'
# 'self into am'-> 'e to she prainst the sur'
# " a woman's t"-> 'he come to the reather t'
# 'for those ea'-> 'rth the sonter of the co'
# 'No, sir, God'-> ' the sond of the courter'
# 'VINCENTIO:\nU'-> 'ries and the reath and t'
# 'd quit it: t'-> 'he sone of the forth and'
# 'Was in the w'-> 'ith a shall be the for t'
# 'n of him.\n\nK'-> 'ING RICHARD II:\nWhere al'
# ' it.\n\nKATHAR'-> 'D:\nShe leare the for the'
# 'he making of'-> ' the cours of the sould '
# 'ace her for '-> 'hear of the earth and th'
# 'stard withou'-> 's the stare the the dord'
# 'n thou cames'-> 't the sone that the to t'
# 'by the way, '-> 'thou art the rown the so'
# 'here did you'-> ' to the sone to the fort'
# 'to him\nDoth '-> 'the down the sorder the '
# 'een.\n\nANTONI'-> 'ES:\nThe done to the fort'
# ' and to him '-> 'his heart the forth of h'
# 'but supposed'-> ' to the his and to the b'
# 's right: we '-> 'the sould to the beart a'
# 'you may; but'-> ' the sone to the forth a'
# ' I am not\nfi'-> 'll the seep the seart th'
# ' you as you '-> 'the bear the bear to the'
# 'NIO:\nIf but '-> 'the seep the seart the b'
# ' eye advance'-> ', the sould the bear the'
# 's the moon t'-> 'he compart the the best '
# ' sacred chas'-> ' the seep the seave the '
# 'ine,\nWould I'-> ' will the propless of th'
# 'k you I can '-> 'and the reto the seart t'
# 'ave us.\n\nBIO'-> 'LINIUS:\nAnd well me the '
# 'ce\non the sc'-> 'all the propless of the '
# ' of him.\n\nPR'-> 'INCE ESWARD:\nThe wart th'
# 'if you be mo'-> 're the stall the bear th'
# 'est and most'-> ' thou will the will the '
# 'e deed was d'-> 'oth the batter that the '
# 'd have sent\n'-> 'That in the lake of the '
# 'dam wife, si'-> 'r be the stand the beath'
# 'atter.\n\nDUKE'-> ' OF YORK:\nI will the pre'
# 'us,\nSit with'-> ' the bearth a peart the '
# 'ghbour.\nNow '-> 'shat stand the beather t'
# 'ANTONIO:\nNay'-> ', by the stand the beath'
# '?\n\nMARIANA:\n'-> 'He look of his mander hi'
# 'Kate,\nAnd bo'-> 'th the counter him to th'
# 'il full purp'-> 'oner.\n\nCORIOLANUS:\nNo, a'
# ', for all th'-> 'e propless of the counte'
# 'er maidenhea'-> 'r the counter him to the'
# 'k or two:\nBu'-> 't the the so my lord, an'
# ' fustian, th'-> 'at the can ont thou so m'
# 'ep afterward'-> ' the counter and the cou'
# 'o not sleep:'-> ' the forth the cands of '
# 'sily heal: a'-> 'nd the sould to the coun'
# 'must be pati'-> 'ent the sone that should'
# 'ould not wed'-> ' the seave the seave the'
# 'e conceit is'-> ' the with the counter an'
# ' block\nWhere'-> ' and the sould the seave'
# 'Art thou his'-> ' the son and the seave t'
# 'LLA:\nO, were'-> ' you here the heart the '
# 'l buckler th'-> 'e sonse that his faired '
# ' loath:\nI wo'-> 'uld the stand to the son'
# ' should die '-> 'the heart the heart the '
# 'lder sister '-> 'the sonse that his faire'
# 'ant garden o'-> 'n the statle stand the s'
# 'And let it b'-> 'e a the heart the with t'
# 'n her son.\n\n'-> 'CORIOLANUS:\nNow the shou'
# 'And dull to '-> 'the sure of the statle s'
# ' he, as if\nH'-> 'ow the sure of the statl'
# 'vised him fo'-> 'rther so maniss of the s'
# ' it not the '-> 'heart the heart the hear'
# 'ou so soon f'-> 'or the seare the heart t'
# 't be hooded,'-> ' the stall the stall the'
# 'skance,\nNor '-> 'the heart the heart the '
# ' are welcome'-> ' to the farth of the som'
# 'u mayst slid'-> 'ed the from the seave th'
# 'our service.'-> '\n\nCAMILLO:\nShe have stan'
# 'd look on me'-> ' the heart of the forth '
# 'd rail upon '-> 'the soor with the counde'
# 'of burr; I s'-> 'ay the stall of the for '
# 'ased him, Is'-> ' my san the from the sea'
# 'e, not kindn'-> 'ess the so man shall be '
# 'y woo her, w'-> 'ho shall she part the th'
# 'catched in t'-> 'he pround the prince and'
# 'ng to see.\n\n'-> 'COMIOLUS:\nI will not the'
# 'in Padua for'-> ' the come to the more th'
# ' still great'-> ' the prince for the son '
# 'est.\n\nDUKE V'-> 'INGEND:\nI will not the c'
# 'tly she doth'-> ' the come to the more th'
# 'h to your da'-> 'y the worther had the sh'
# 'so disfigure'-> 's what a say the worther'
# ' advise\nYou '-> 'there all the worther ha'
# 'uckold.\n\nDUK'-> 'E OF AUMERLE:\nWhat my no'
# 'in the hole,'-> ' and the worthe worther '
# 'ell read in '-> 'the son and the stall of'
# 'you to seek '-> 'the sould the say the so'
# 's Lucentio?\n'-> '\nGLOUCESTER:\nThat is the'
# 't,\nSo happy '-> 'it is the son and the st'
# 'ive.\n\nMARIAN'-> 'IE:\nA and the shall be s'
# 'other lectur'-> 'e the be the say to the '
# 'ind embracem'-> 'bers to the sain to the '
# ' me and be n'-> 'ot the torth of the word'
# 'er down.\n\nHO'-> 'RTHUMES:\nI do be the to '
# 'r abominable'-> ' the stain the came to t'
# 'd with her b'-> 'e the heart of the cours'
# 'hanging.\n\nDU'-> 'CHESS OF YORK:\nAnd what '
# " unsoil'd na"-> 'th the course of heart t'
# 'y a fool\nto '-> 'the sour son the surver '
# 'or Gremio, c'-> 'ome to his hearth on my '
# 'highness sai'-> 'nted the pray of the wou'
# 'ports your g'-> 'race and the seart to th'
# 'if any crave'-> ' the parthe and the come'
# 'KE VINCENTIO'-> ':\nThe well the warth of '
# 'HORTENSIO:\nF'-> 'or the the parthe and th'
# 'will sue to '-> 'the prince and the could'
# 'matches neve'-> 'r and the constion.\n\nMEN'
# ' best\nhorse '-> 'of the words of the word'
# ' drinking al'-> 'l the world the comes of'
# 'cation\nTo lo'-> 'rd the world the comes o'
# 'ldst have he'-> 're the words of the word'
# 'e half of my'-> ' heart the the the the t'
# 'hile you tak'-> 'e the the to the the to '
# 'oath,\nI will'-> ' be the the to the the t'
# 'ble monument'-> ' the the the the the the'
# 'ed un and br'-> 'other have of his prince'
# 'for the fair'-> ' the with the seave the '
# 'pecial busin'-> 'ess to the seart of his '
# ' madness.\n\nI'-> 'SCALUS:\nWhat say the sha'
# 'ed with\nspav'-> 'e the that with the seav'
# 'y grief.\n\nPE'-> 'LERIA:\nI may the seave t'
# 'et his honou'-> 'r heart the such a dear '
# '! slave! Cal'-> 'l the seare the seepless'
# 'tion, which '-> 'a stall of his letter th'
# 'e doth court'-> 'er the sence the seep a '
# 'ort your man'-> ' the peace the parter of'
# 'rovost?\n\nDUK'-> 'E OF YORK:\nA dear the se'
# 'TRUCHIO:\nNay'-> ', by the would not so th'
# 'instrument,\n'-> 'And we the should be the'
# 'then: neithe'-> 'r the worther words the '
# ';\nI leave hi'-> 'm so man the propest the'
# 'nd must be b'-> 'rother to the prince of '
# 'ou read no o'-> 'ne the prople and the pr'
# 'm for drowni'-> 'ng the say to the parth '
# 'rought repri'-> 'ng the prople and the pr'
# '\nAnd left th'-> 'e parth the prose that t'
# ' it much to '-> 'the warth the may the so'
# 'had not a sp'-> 'eak the fair the senter '
# 'good father.'-> '\n\nCAMILLO:\nI man the sho'
# 'd this maid:'-> '\nWhen the should be the '
# 'd for her,\nS'-> 'o bland the but the stai'
# 'anca, so bel'-> 'is the grace of the peac'
# 'Minola,\nAn a'-> 'll the seare the conself'
# 'what am I, s'-> 'hall be the seart the co'
# ' your worshi'-> 's shall be stand the con'
# ' the third m'-> 'e so the consent the sen'
# ' having the '-> 'condon the grace of the '
# 'and in him m'-> 'y sence to the consent t'
# 'hereof;\nFor '-> 'the good of the more the'
# 'Servants, le'-> 't the sen the consent th'
# 'his new-marr'-> 'y hath the heart the bea'
# 'that Petruch'-> ' and him stand the const'
# 'd not like a'-> ' that the seept is this '
# 'so.\n\nPETRUCH'-> 'ESS OF YORK:\nA dear the '
# ', fie, fie!\n'-> '\nCAMILLO:\nWhat is the to'
# 'l you, sir, '-> 'and the seare the compos'
# 'me on, I say'-> ' be sone to be the compo'
# 's I have hea'-> 'rd the bear the send the'
# '\nIn token of'-> " the counter'd but the f"
# 'NZALO:\nI do '-> 'be and to be the compose'
# 'wear her,\nAs'-> ' in the lord of the fort'
# 'is master! L'-> 'ord the hear the self th'
# "t's beauty's"-> ' for the world the words'
# "me honour'd "-> 'the conder of the for th'
# 'IO:\nO, sir, '-> 'the with the death of th'
# ':\nYou rogue,'-> ' and the shall the warth'
# 'ith his oath'-> ' the seare the that have'
# 'ches, misrep'-> ' the that the shall the '
# ' is in our p'-> 'ropest the the worth the'
# 'l day.\n\nDUKE'-> ' OF YORK:\nI do the man t'
# 'upon the wat'-> 'h he would be the consen'
# 'MIO:\nBut thi'-> 's she will be the hath t'
# 'a foul conte'-> 'r of the for the could t'
# ': his subjec'-> 'tion, that should be the'
# 'he sun break'-> 'ent the shall be the con'
# ', and I have'-> ' me the sent of the eart'
# 'ut sun it is'-> ' the heart the man the c'
# 'e so full of'-> ' the self the seep the s'
# 'love have to'-> ' the will be the hand th'
# 'ned conseque'-> ' the hath the man and th'
# 'ague below t'-> 'he wast the speak the fa'
# 'UKE VINCENTI'-> 'O:\nThe shall the warth t'
# 'o spangle he'-> 'art the son and the stal'
# 'nce we have '-> 'sone the son and the sta'
# 'n my love,\nH'-> 'ere you shall be the son'
# 'l I please m'-> 'e some prove the to make'
# ', I pray the'-> ' good me better the the '
# 'n my life; a'-> 'nd here a morder here th'
# ' not pay for'-> ' the would not be a mort'
# 'e commits hi'-> 'm to man the read to the'
# 'ith thanks;\n'-> 'And where the words of t'
# 'ed; my maste'-> 'r to the for the country'
# 'nd shrewd\nTh'-> 'e son the country and th'
# ' so formal, '-> 'for the world the was a '
# 'ves for him:'-> '\nI have done the to the '
# 'ousand crown'-> ' and the ware and there '
# 'ts than back'-> ' the warks and the parth'
# 'n hazard.\nCl'-> 'irst the seave the reast'
# "h o' the sea"-> 'rt the that have stand t'
# 'eit in that?'-> '\n\nGLOUCESTER:\nThe stay t'
# 'y, Pompey, t'-> 'he was a prove the dise '
# 'e, sure, mor'-> 'e with the daughter with'
# "O:\n'Tis well"-> ' the warth the cause tha'
# 'ouse you\nJoi'-> 'ng and the with a seep i'
# 'or the name '-> 'of the with the daughter'
# ' be cross in'-> ' the father that we hath'
# ':\nFor he fea'-> 'red the seave the come t'
# '? I say,\nMy '-> 'lord, the father that we'
# "st thou e'er"-> ' the with the can of the'
# '.\n\nDUKE VINC'-> 'ENTIO:\nThere is the wart'
# 'e happily me'-> ' to my songer of the pro'
# 'To a determi'-> 'ng the parth the father '
# 'NCENTIO:\nTha'-> 't is the propless of the'
# ', none so dr'-> 'eat son part the parth t'
# 'ranted in co'-> 'me to my present and the'
# 'n resolution'-> ' the courself the sent t'
# 'ommodity lay'-> ' the for the could the c'
# ' will better'-> ' than the soul streat th'
# 'astical duke'-> ' thee well the consent t'
# 'ed of any en'-> 'eed to me.\n\nCLARENCE:\nI '
# 'ust away to-'-> 'seed them the what we co'
# 'froward, pee'-> 'pert the hath the would '
# 'e them frien'-> 'ds and the counder that '
# 'im not die. '-> 'The what the state of th'
# ' in autumn c'-> 'ommon the heart the with'
# 'honour not y'-> 'our sing and to the brot'
# 'd within her'-> 'e the sain the san the s'
# ' it were Mis'-> 'tarent and the state of '
# 'ient, sweet '-> 'a shall be so me the hea'
# 'te thou cans'-> 't the stand of the rest '
# 'TRUCHIO:\nGen'-> 'tleman:\nMy lord, I world'
# 'of thread?\nA'-> 'nd then the stand the st'
# 'o me as secr'-> 'ed the stand of the reat'
# ' her lure.\nA'-> 'nd the stand of the reat'
# ', your occup'-> 'itions the state of the '
# ' do you litt'-> 'er that the state of the'
# '\n\nTRANIO:\nO,'-> ' then mother that we com'
# 'ch garments,'-> ' that we shall be the st'
# 'of Lord\nAnge'-> 'ntle the counder with a '
# 'NCENTIO:\nLuc'-> 'k it is the counted the '
# 're of the fo'-> 'r the see the cause the '
# 'reat Italy;\n'-> 'The shall the warsh powe'
# 'thee straigh'-> 't the seeple the sees a '
# 'eld that spe'-> 'ak the fair the seeple t'
# 'be made?\n\nGR'-> 'OUCESTER:\nWhat is the se'
# 'is?\nCall for'-> ' the son of the counter '
# 'auble, throw'-> 'n the say the call the w'
# '\nBIANCA:\nIs '-> 'the son, the selfor the '
# 'at she will '-> 'not the forth of the say'
# ' friend, wha'-> 't say the with the canse'
# 'and mine\nOut'-> ' the man and the rest th'
# 'guise shall,'-> ' and the rest the reast '
# 't spend all '-> 'the with the say the war'
# 'trikes. What'-> ' hath see and with the s'
# 'leave: havin'-> 'g that have so make and '
# 'My lord, she'-> ' love the seep the seeve'
# '\nmy master a'-> 'nd the compless the see '
# 'ek redemptio'-> 'n so his conself the see'
# 'y head, thy '-> 'seed the sees the sees t'
# 'yours.\n\nProv'-> 'e:\nSee the may the conse'
# 'Thank you. W'-> 'arch and the father we t'
# '\nthat frailt'-> ' the propert the hath a '
# 'a merciful m'-> 'anter the heart the fath'
# 'gging whiles'-> ' me here the earth the b'
# 'mends!\n\nALL:'-> '\nNow our bear to the fat'
# ' of you,\nTha'-> 't she parthe hands and t'
# ', my gentle '-> 'and the cause the father'
# "r,\nDash'd al"-> 'l the prince the father '
# 't.\nSir, this'-> " mander'd speake the fai"
# 'll be so for'-> 'th the cause of him and '
# ' Kate; for t'-> 'he see the cause the con'
# "e to nod I'l"-> 'l the words the seart th'
# 'nightingale:'-> '\nThe bear the seare the '
# 'tance that y'-> 'ou shall the seare the t'
# "d 'em,\nOr el"-> 'lest thou art the rest t'
# 'ur blood,\nAn'-> 'd then the seave the hea'
# ' say I am no'-> 't of the hath thee and t'
# '; he doth bu'-> 't the from the seart tho'
# 'siness: I da'-> 'y the seave the heart th'
# 'Go take her '-> 'some to the friends and '
# 'INCENTIO:\nO,'-> ' the shall be the prince'
# 'y!\n\nDUKE VIN'-> 'CENTIO:\nThe pook the fat'
# 'queen of Car'-> 'ience, and the shall be '
# 'oose.\nCome a'-> 'nd the common the forth '
# ', not I I ha'-> 've hear the father that '
# 'ice; that I '-> 'have thee there the sent'
# 'nefit; redee'-> 'd the sentleman the sons'
# '\nhe would mo'-> 'ther sold the selper the'
# 'e.\nSo, bring'-> ' the songer of the sount'
# 'y, man, ther'-> 'e to my lord, the great '
# 'IO:\nFaith, a'-> 'nd the common the selp t'
# 'er by hersel'-> 'f they so more the compa'
# 'RUMIO:\nThere'-> ' is the sender the commo'
# 'ther busines'-> "s to the counter'd the s"
# 'eous gentlem'-> 'an the son the compon th'
# '\nI see a wom'-> 'an the seart the with th'
# 'CENTIO:\nSile'-> ' me the seart the with t'
# 'burden thee;'-> ' and the stand the seart'
# 'day.\n\nDUKE V'-> 'INCENTIO:\nThe part the w'
# 's request,\nA'-> 'nd then the stain a bast'
# ' your sister'-> 's, and the rest the seep'
# "ith raven's "-> 'shall be sone and the st'
# 'ORSON:\nGo in'-> ' the come to see the see'
# 'ess;\nSay, I '-> 'do not stand will be the'
# " have ta'en "-> 'the shall be sone and th'
# 'feits in a b'-> 'ear to the come of the s'
# 'watch your s'-> 'onour country, the soul '
# 'e drawn betw'-> 'er.\n\nSICINIUS:\nHe will t'
# 'hand is read'-> ' to the morth the more o'
# 'ou know\nMy d'-> 'ays the some of the soun'
# "ed'st body t"-> 'he grown and there he sh'
# 's you would '-> 'not stand the crown and '
# 'y of marriag'-> 'e the prople of the prin'
# 'is a word or'-> ' heart the truth the dis'
# ' him in the '-> 'pronce of the prince the'
# 'amut in a br'-> 'ow the the should be the'
# "e employ'd a"-> 'nd the state of your goo'
# 'that you sen'-> 'ce to see the soul strea'
# 'sullen,\nAnd '-> 'then the state and the c'
# 'to end succe'-> 'ssion of the may some to'
# 'nature shoul'-> 'd be the but of the rest'
# 'er.\n\nPETRUCH'-> 'ESS OF YORK:\nWhy loven b'
# 'boatswain, h'-> 'e world be the but of th'
# 'ow too forwa'-> 'rd with the lands of his'
# " call'st tho"-> 'u there of the prince th'
# 'Heaven shiel'-> 'd the prover of the comp'
# 'his shall ab'-> 'our house.\n\nSecond Murde'
# 's father is '-> 'the prince the present t'
# ' sun be set:'-> ' they shall the the down'
# 'racious duke'-> ' of the prince the prese'
# 'ld slide: se'-> 't the see the prove the '
# 'o play a ple'-> 'ased the shall be the st'
# '?\n\nTRANIO:\nO'-> ' be shall be the stand o'
# ' it, you may'-> ' the sould be the bear t'
# ' you speak t'-> 'o the shall be the stand'
# 'irst, his in'-> ' the come to me the come'
# ' home, he ha'-> 'th so many the say to th'
# "he's hid:\nTh"-> 'e ward the world the wor'
# '\n\nGONZALO:\nA'-> 'nd that I will not stand'
# 'a,\nAnd her w'-> 'ords the world the world'
# 'y harmony:\nT'-> 'hen she hath seen the cr'
# 'uted, and sl'-> 'ough the heart the well '
# 'inks you fro'-> 'm the selves and his sha'
# ' why, your m'-> 'any all the wing and the'
# 'et, as they '-> 'shall be the best the se'
# 'orities ther'-> 'e of his country of the '
# 'before and w'-> 'ith the state of the wor'
# 'RUCHIO:\nI sa'-> 'y the soul sir, a should'
# 'h such beaut'-> 'ed the state of the worl'
# 'ANGELO:\nHapp'-> 'y to me to me the come t'
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▇▅▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>1.57991</td></tr><tr><td>val_loss</td><td>1.84766</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">robust-wave-140</strong> at: <a href='https://wandb.ai/llmnerds/my-awesome-project/runs/a20m2ovc' target="_blank">https://wandb.ai/llmnerds/my-awesome-project/runs/a20m2ovc</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230930_201424-a20m2ovc/logs</code>

# %%
prompts = get_batch(val_data, ctx_len=CTX_LEN, batch_size=5)[0].to(device)

# %%
generated = generate(
    model=model,
    model_params=model_params,
    encoded_prompt=prompts,
    ctx_len=CTX_LEN,
    n_tokens=300,
)
for p in generated:
    char_list = p.tolist()
    pre_prompt = char_list[:CTX_LEN]
    post_prompt = char_list[CTX_LEN:]

    print(f"{repr(decode(pre_prompt))}-> {repr(decode(post_prompt))}")
# Out:
# 'orities ther'-> 'e are the sen the words and the state of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sear'
# 'before and w'-> 'ith the stain and the well as the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the wi'
# 'RUCHIO:\nI sa'-> 'y the state of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of'
# 'h such beaut'-> 'ed the state of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears o'
# 'ANGELO:\nHapp'-> 'y the the see the words and the state of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sears of the with the sear'

# %%
import json
d = json.load(open("tmp/data00.json", "r"))

# %%
# Out:
# {'story': "Once upon a time, there was a cute puppy named Max. Max was very adorable with his big, brown eyes and wagging tail. One day, Max's owner, Emily, told him that they needed to go to the post office to mail a letter. Max didn't know what that meant, but he was excited to go for a car ride.\nAt the post office, Emily gave the letter to the nice lady behind the desk. The lady asked Emily for a number and Emily gave her one. Max didn't know what a number was, but he saw the lady type something on the computer.\nAfter they mailed the letter, Emily and Max went back to the car. Max was happy that they went on an adventure and he couldn't wait for the next one.",
#  'instruction': {'prompt:': 'Write a short story (3-5 paragraphs) which only uses very simple words that a 3 year old child would understand. In the story, try to at some point use the verb "mail", the noun "number" and the adjective "adorable". Remember to only use simple words!',
#   'words': ['mail', 'number', 'adorable'],
#   'features': []},
#  'summary': 'Max goes on a car ride with his owner to the post office and watches her mail a letter.',
#  'source': 'GPT-3.5'}
